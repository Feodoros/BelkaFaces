# %%
import cv2
import numpy as np
import os

# %%
def frames_to_video(inputpath,outputpath,fps):
    image_array = []
    files = [f for f in os.listdir(inputpath) if isfile(join(inputpath, f))]
    files.sort(key = lambda x: int(x[5:-4]))
    for i in range(len(files)):
        img = cv2.imread(inputpath + files[i])
        size =  (img.shape[1],img.shape[0])
        img = cv2.resize(img,size)
        image_array.append(img)
    fourcc = cv2.VideoWriter_fourcc('D', 'I', 'V', 'X')
    out = cv2.VideoWriter(outputpath,fourcc, fps, size)
    for i in range(len(image_array)):
        out.write(image_array[i])
    out.release()

# %%
inputpath = 'Test\AngleTest\Frames'
outpath =  'Test\AngleTest\IMG_7168.MOV'
fps = 8
frames_to_video(inputpath,outpath,fps)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-18-49719a2ee51d> in <module>
#       2 outpath =  'Test\AngleTest\IMG_7168.MOV'
#       3 fps = 8
# ----> 4 frames_to_video(inputpath,outpath,fps)
#
# <ipython-input-17-62ce97a1f3db> in frames_to_video(inputpath, outputpath, fps)
#       9         image_array.append(img)
#      10     fourcc = cv2.VideoWriter_fourcc('D', 'I', 'V', 'X')
# ---> 11     out = cv2.VideoWriter(outputpath,fourcc, fps, size)
#      12     for i in range(len(image_array)):
#      13         out.write(image_array[i])
#
# UnboundLocalError: local variable 'size' referenced before assignment

# %%
import cv2
vidcap = cv2.VideoCapture('Test\AngleTest\IMG_7168.MOV')
success,image = vidcap.read()
count = 0
while success:
    if (True):
        cv2.imwrite("Test\\AngleTest\\Frames\\" + "frame%d.jpg" % count, image)     # save frame as JPEG file      
        success,image = vidcap.read()
        print('Read a new frame: ', success)
    count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
vidcap = cv2.VideoCapture('Test\AngleTest\IMG_7168.MOV')
success,image = vidcap.read()

# %%
count = 0
for image in os.listdir("Test\\AngleTest\\Frames"):
    if(count%3 != 0):
        os.remove("Test\\AngleTest\\Frames\\" + image)
    count += 1
